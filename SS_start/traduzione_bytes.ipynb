# %% [markdown]
# van_haven

# %%
cod = [ 0x66, 0x6d, 0x63, 0x64, 0x7f, 0x62, 0x36, 0x58, 0x3c, 0x61, 0x39, 0x6a, 0x68, 0x52, 0x3a, 0x61, 0x74, 0x4e, 0x78, 0x66, 0x79, 0x65, 0x6b, 0x17 ]


flag = []

for i in range(24):
    flag.append( cod[i] ^ i)
    
string = bytes(flag) 
print(string)

# %%
l = [-0x3d09,-0x900,-0x2341,-0x27d9,-0x3490,-0x2f44,-0x24c1,-0x2f44,-0x2f44,-0x2e69,-0x32c4,-0x27d9,-0x,-0x24c13490,-0xa29,-0x3b19,-0x2971,-0x2d90,-0x28a4]
